# %%
import pandas as pd

data = '2000-01-01-2019-06-21-Iraq.csv'

# %%
df = pd.read_csv(data)
df.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty    event_date  year  \
# 0  5218676  368      IRQ20482             20482  15 June 2019  2019
# 1  5218632  368      IRQ20459             20459  15 June 2019  2019
# 2  5218588  368      IRQ20436             20436  14 June 2019  2019
# 3  5218596  368      IRQ20441             20441  14 June 2019  2019
# 4  5218598  368      IRQ20442             20442  14 June 2019  2019
#
#    time_precision                  event_type  \
# 0               1  Explosions/Remote violence
# 1               1      Strategic developments
# 2               1                    Protests
# 3               2  Explosions/Remote violence
# 4               2                     Battles
#
#                       sub_event_type  \
# 0                   Air/drone strike
# 1       Looting/property destruction
# 2                   Peaceful protest
# 3  Shelling/artillery/missile attack
# 4                        Armed clash
#
# ...

# %%
for i in df.admin1.unique():
    print(i)
# Out:
# Erbil
# Ninewa
# Baghdad
# Sala al-Din
# Babylon
# Anbar
# Diyala
# Kirkuk
# Dahuk
# Basrah
# Qadissiya
# Sulaymaniyah
# Kerbala
# Thi-Qar
# Muthanna
# Najaf
# Wassit
# Missan

# %%
df_erbil_ninewa = df[df.admin1.isin(['Erbil', 'Ninewa'])]
for i in df_erbil_ninewa.admin1.unique():
    print(i)
# Out:
# Erbil
# Ninewa

# %%
for i in df_erbil_ninewa.event_type.unique():
    print(i)
# Out:
# Explosions/Remote violence
# Strategic developments
# Battles
# Violence against civilians
# Protests
# Riots

# %%
for i in df_erbil_ninewa.sub_event_type.unique():
    print(i)
# Out:
# Air/drone strike
# Looting/property destruction
# Armed clash
# Remote explosive/landmine/IED
# Disrupted weapons use
# Attack
# Change to group/activity
# Shelling/artillery/missile attack
# Peaceful protest
# Other
# Abduction/forced disappearance
# Grenade
# Mob violence
# Arrests
# Suicide bomb
# Protest with intervention
# Violent demonstration
# Headquarters or base established
# Non-violent transfer of territory
# Government regains territory
# Non-state actor overtakes territory
# Chemical weapon
# Excessive force against protesters

# %%
df_events = df_erbil_ninewa.groupby(['event_type','sub_event_type']).size().reset_index().rename(columns={0:'count'})
df_events
# Out:
#                     event_type                       sub_event_type  count
# 0                      Battles                          Armed clash   1490
# 1                      Battles         Government regains territory    743
# 2                      Battles  Non-state actor overtakes territory     10
# 3   Explosions/Remote violence                     Air/drone strike   2986
# 4   Explosions/Remote violence                      Chemical weapon     17
# 5   Explosions/Remote violence                              Grenade     12
# 6   Explosions/Remote violence        Remote explosive/landmine/IED    375
# 7   Explosions/Remote violence    Shelling/artillery/missile attack    338
# 8   Explosions/Remote violence                         Suicide bomb     70
# 9                     Protests   Excessive force against protesters      1
# 10                    Protests                     Peaceful protest     42
# ...

# %%
df_events['count'].sum()
# Out:
# 6956
